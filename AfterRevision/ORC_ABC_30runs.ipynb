# %%
from orc_meta_common import ABC, run_algorithm_experiments, save_single_algorithm_outputs

if __name__ == "__main__":
    N_RUNS = 30
    POP_SIZE = 100
    ITERATIONS = 1000
    PENALTY_WEIGHT = 1e6
    BASE_SEED = 123

    problem, results, summary = run_algorithm_experiments(
        optimizer_cls=ABC,
        algorithm_name="ABC",
        n_runs=N_RUNS,
        P=POP_SIZE,
        G=ITERATIONS,
        penalty_weight=PENALTY_WEIGHT,
        base_seed=BASE_SEED,
        optimizer_kwargs={},
    )

    save_single_algorithm_outputs(
        problem=problem,
        results=results,
        summary=summary,
        algorithm_name="ABC",
        outdir_name="outputs_abc",
    )
# Out:
# ====================================================================================================
# ABC ON THE ORC PROBLEM
# ====================================================================================================
# Run 01 | ABC | Feasible: True | Best Fitness (sum_ti): 6.900460
# Run 02 | ABC | Feasible: True | Best Fitness (sum_ti): 6.900144
# Run 03 | ABC | Feasible: True | Best Fitness (sum_ti): 6.900221
# Run 04 | ABC | Feasible: True | Best Fitness (sum_ti): 6.900090
# Run 05 | ABC | Feasible: True | Best Fitness (sum_ti): 6.900174
# Run 06 | ABC | Feasible: True | Best Fitness (sum_ti): 6.900388
# Run 07 | ABC | Feasible: True | Best Fitness (sum_ti): 6.900075
# Run 08 | ABC | Feasible: True | Best Fitness (sum_ti): 6.900139
# Run 09 | ABC | Feasible: True | Best Fitness (sum_ti): 6.900279
# Run 10 | ABC | Feasible: True | Best Fitness (sum_ti): 6.900300
# Run 11 | ABC | Feasible: True | Best Fitness (sum_ti): 6.900170
# Run 12 | ABC | Feasible: True | Best Fitness (sum_ti): 6.900173
# Run 13 | ABC | Feasible: True | Best Fitness (sum_ti): 6.900219
# Run 14 | ABC | Feasible: True | Best Fitness (sum_ti): 6.900073
# Run 15 | ABC | Feasible: True | Best Fitness (sum_ti): 6.900107
# Run 16 | ABC | Feasible: True | Best Fitness (sum_ti): 6.900529
# Run 17 | ABC | Feasible: True | Best Fitness (sum_ti): 6.900195
# Run 18 | ABC | Feasible: True | Best Fitness (sum_ti): 6.900041
# Run 19 | ABC | Feasible: True | Best Fitness (sum_ti): 6.900210
# Run 20 | ABC | Feasible: True | Best Fitness (sum_ti): 6.900174
# Run 21 | ABC | Feasible: True | Best Fitness (sum_ti): 6.900474
# Run 22 | ABC | Feasible: True | Best Fitness (sum_ti): 6.900190
# Run 23 | ABC | Feasible: True | Best Fitness (sum_ti): 6.900276
# Run 24 | ABC | Feasible: True | Best Fitness (sum_ti): 6.900132
# Run 25 | ABC | Feasible: True | Best Fitness (sum_ti): 6.900326
# Run 26 | ABC | Feasible: True | Best Fitness (sum_ti): 6.900107
# Run 27 | ABC | Feasible: True | Best Fitness (sum_ti): 6.900142
# Run 28 | ABC | Feasible: True | Best Fitness (sum_ti): 6.900139
# Run 29 | ABC | Feasible: True | Best Fitness (sum_ti): 6.900270
# Run 30 | ABC | Feasible: True | Best Fitness (sum_ti): 6.900292
#
# ==============================================================================================================
# SUMMARY TABLE
# ==============================================================================================================
# Rank  Algorithm         Feasible    Mean          Std           Min           Max
# 1     ABC               30/30       6.900217      0.000121      6.900041      6.900529
#
# Best feasible run for ABC
# Relay     td          Ip(A)       Ti(s)
# Relay-1   0.556634    117.152     1.600036
# Relay-2   0.452277    523.000     1.300004
# Relay-3   0.388181    400.000     1.000001
# Relay-4   0.354645    500.000     1.000000
# Relay-5   0.327356    600.000     1.000000
# Relay-6   0.388180    400.000     1.000000
#
# Constraint Check:
# 1 <= t1 <= 2.2 : True
# 1 <= t2 <= 2.2 : True
# 1 <= t3 <= 2.2 : True
# 1 <= t4 <= 2.2 : True
# 1 <= t5 <= 2.2 : True
# 1 <= t6 <= 2.2 : True
# t1 - t2 >= 0.3 : True   value = 0.300032
# t2 - t3 >= 0.3 : True   value = 0.300003
# t2 - t4 >= 0.3 : True   value = 0.300004
# t2 - t5 >= 0.3 : True   value = 0.300004
# t2 - t6 >= 0.3 : True   value = 0.300004
#
# Best fitness (sum_ti): 6.900041
# Function evaluations: 199901
#
# ====================================================================================================================================================================================
# OPTIMAL RELAY COORDINATION PARAMETERS (TD, IP, TI) AND TOTAL RUN TIMES
# OBTAINED FROM THE ABC ALGORITHM
# ====================================================================================================================================================================================
# Algorithm         Relay-1 (td, Ip, ti)        Relay-2 (td, Ip, ti)        Relay-3 (td, Ip, ti)        Relay-4 (td, Ip, ti)        Relay-5 (td, Ip, ti)        Relay-6 (td, Ip, ti)        Total ti
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ABC               0.5566 / 117.15 / 1.6000    0.4523 / 523.00 / 1.3000    0.3882 / 400.00 / 1.0000    0.3546 / 500.00 / 1.0000    0.3274 / 600.00 / 1.0000    0.3882 / 400.00 / 1.0000    6.9000
#
# Saved summary CSV: C:\Users\ESEL\Desktop\SGuA\SGuA_rev\outputs_abc\abc_orc_summary_statistics.csv
# Saved run-level CSV: C:\Users\ESEL\Desktop\SGuA\SGuA_rev\outputs_abc\abc_orc_run_results.csv
# Saved publication CSV: C:\Users\ESEL\Desktop\SGuA\SGuA_rev\outputs_abc\abc_orc_publication_table.csv
# Saved convergence CSV: C:\Users\ESEL\Desktop\SGuA\SGuA_rev\outputs_abc\abc_or_c_feasible_curves.csv
# Saved distribution figure: C:\Users\ESEL\Desktop\SGuA\SGuA_rev\outputs_abc\abc_orc_distribution_boxplot.png
# Saved convergence figure: C:\Users\ESEL\Desktop\SGuA\SGuA_rev\outputs_abc\abc_orc_mean_convergence.png
