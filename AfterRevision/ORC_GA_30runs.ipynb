# %%
from orc_meta_common import GA, run_algorithm_experiments, save_single_algorithm_outputs

if __name__ == "__main__":
    N_RUNS = 30
    POP_SIZE = 100
    ITERATIONS = 1000
    PENALTY_WEIGHT = 1e6
    BASE_SEED = 123

    problem, results, summary = run_algorithm_experiments(
        optimizer_cls=GA,
        algorithm_name="GA",
        n_runs=N_RUNS,
        P=POP_SIZE,
        G=ITERATIONS,
        penalty_weight=PENALTY_WEIGHT,
        base_seed=BASE_SEED,
        optimizer_kwargs={},
    )

    save_single_algorithm_outputs(
        problem=problem,
        results=results,
        summary=summary,
        algorithm_name="GA",
        outdir_name="outputs_ga",
    )
# Out:
# ====================================================================================================
# GA ON THE ORC PROBLEM
# ====================================================================================================
# Run 01 | GA | Feasible: True | Best Fitness (sum_ti): 6.900385
# Run 02 | GA | Feasible: True | Best Fitness (sum_ti): 6.901179
# Run 03 | GA | Feasible: True | Best Fitness (sum_ti): 6.900558
# Run 04 | GA | Feasible: True | Best Fitness (sum_ti): 6.900423
# Run 05 | GA | Feasible: True | Best Fitness (sum_ti): 6.900432
# Run 06 | GA | Feasible: True | Best Fitness (sum_ti): 6.900188
# Run 07 | GA | Feasible: True | Best Fitness (sum_ti): 6.900750
# Run 08 | GA | Feasible: True | Best Fitness (sum_ti): 6.900601
# Run 09 | GA | Feasible: True | Best Fitness (sum_ti): 6.900823
# Run 10 | GA | Feasible: True | Best Fitness (sum_ti): 6.900461
# Run 11 | GA | Feasible: True | Best Fitness (sum_ti): 6.900408
# Run 12 | GA | Feasible: True | Best Fitness (sum_ti): 6.900848
# Run 13 | GA | Feasible: True | Best Fitness (sum_ti): 6.900827
# Run 14 | GA | Feasible: True | Best Fitness (sum_ti): 6.900930
# Run 15 | GA | Feasible: True | Best Fitness (sum_ti): 6.900570
# Run 16 | GA | Feasible: True | Best Fitness (sum_ti): 6.901112
# Run 17 | GA | Feasible: True | Best Fitness (sum_ti): 6.900252
# Run 18 | GA | Feasible: True | Best Fitness (sum_ti): 6.900844
# Run 19 | GA | Feasible: True | Best Fitness (sum_ti): 6.900713
# Run 20 | GA | Feasible: True | Best Fitness (sum_ti): 6.900658
# Run 21 | GA | Feasible: True | Best Fitness (sum_ti): 6.900651
# Run 22 | GA | Feasible: True | Best Fitness (sum_ti): 6.900446
# Run 23 | GA | Feasible: True | Best Fitness (sum_ti): 6.901201
# Run 24 | GA | Feasible: True | Best Fitness (sum_ti): 6.900720
# Run 25 | GA | Feasible: True | Best Fitness (sum_ti): 6.900452
# Run 26 | GA | Feasible: True | Best Fitness (sum_ti): 6.900577
# Run 27 | GA | Feasible: True | Best Fitness (sum_ti): 6.900439
# Run 28 | GA | Feasible: True | Best Fitness (sum_ti): 6.900893
# Run 29 | GA | Feasible: True | Best Fitness (sum_ti): 6.900575
# Run 30 | GA | Feasible: True | Best Fitness (sum_ti): 6.900843
#
# ==============================================================================================================
# SUMMARY TABLE
# ==============================================================================================================
# Rank  Algorithm         Feasible    Mean          Std           Min           Max
# 1     GA                30/30       6.900659      0.000253      6.900188      6.901201
#
# Best feasible run for GA
# Relay     td          Ip(A)       Ti(s)
# Relay-1   0.556631    117.158     1.600065
# Relay-2   0.452254    523.119     1.300064
# Relay-3   0.387023    403.110     1.000023
# Relay-4   0.353923    502.413     1.000000
# Relay-5   0.327139    600.883     1.000010
# Relay-6   0.388188    400.007     1.000025
#
# Constraint Check:
# 1 <= t1 <= 2.2 : True
# 1 <= t2 <= 2.2 : True
# 1 <= t3 <= 2.2 : True
# 1 <= t4 <= 2.2 : True
# 1 <= t5 <= 2.2 : True
# 1 <= t6 <= 2.2 : True
# t1 - t2 >= 0.3 : True   value = 0.300001
# t2 - t3 >= 0.3 : True   value = 0.300041
# t2 - t4 >= 0.3 : True   value = 0.300064
# t2 - t5 >= 0.3 : True   value = 0.300054
# t2 - t6 >= 0.3 : True   value = 0.300039
#
# Best fitness (sum_ti): 6.900188
# Function evaluations: 100000
#
# ====================================================================================================================================================================================
# OPTIMAL RELAY COORDINATION PARAMETERS (TD, IP, TI) AND TOTAL RUN TIMES
# OBTAINED FROM THE GA ALGORITHM
# ====================================================================================================================================================================================
# Algorithm         Relay-1 (td, Ip, ti)        Relay-2 (td, Ip, ti)        Relay-3 (td, Ip, ti)        Relay-4 (td, Ip, ti)        Relay-5 (td, Ip, ti)        Relay-6 (td, Ip, ti)        Total ti
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# GA                0.5566 / 117.16 / 1.6001    0.4523 / 523.12 / 1.3001    0.3870 / 403.11 / 1.0000    0.3539 / 502.41 / 1.0000    0.3271 / 600.88 / 1.0000    0.3882 / 400.01 / 1.0000    6.9002
#
# Saved summary CSV: C:\Users\ESEL\Desktop\SGuA\SGuA_rev\outputs_ga\ga_orc_summary_statistics.csv
# Saved run-level CSV: C:\Users\ESEL\Desktop\SGuA\SGuA_rev\outputs_ga\ga_orc_run_results.csv
# Saved publication CSV: C:\Users\ESEL\Desktop\SGuA\SGuA_rev\outputs_ga\ga_orc_publication_table.csv
# Saved convergence CSV: C:\Users\ESEL\Desktop\SGuA\SGuA_rev\outputs_ga\ga_or_c_feasible_curves.csv
# Saved distribution figure: C:\Users\ESEL\Desktop\SGuA\SGuA_rev\outputs_ga\ga_orc_distribution_boxplot.png
# Saved convergence figure: C:\Users\ESEL\Desktop\SGuA\SGuA_rev\outputs_ga\ga_orc_mean_convergence.png
