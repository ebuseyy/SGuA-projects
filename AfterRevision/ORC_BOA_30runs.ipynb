# %%
from orc_meta_common import BOA, run_algorithm_experiments, save_single_algorithm_outputs

if __name__ == "__main__":
    N_RUNS = 30
    POP_SIZE = 100
    ITERATIONS = 1000
    PENALTY_WEIGHT = 1e6
    BASE_SEED = 123

    problem, results, summary = run_algorithm_experiments(
        optimizer_cls=BOA,
        algorithm_name="BOA",
        n_runs=N_RUNS,
        P=POP_SIZE,
        G=ITERATIONS,
        penalty_weight=PENALTY_WEIGHT,
        base_seed=BASE_SEED,
        optimizer_kwargs={},
    )

    save_single_algorithm_outputs(
        problem=problem,
        results=results,
        summary=summary,
        algorithm_name="BOA",
        outdir_name="outputs_boa",
    )
# Out:
# ====================================================================================================
# BOA ON THE ORC PROBLEM
# ====================================================================================================
# Run 01 | BOA | Feasible: False | No feasible solution found
# Run 02 | BOA | Feasible: False | No feasible solution found
# Run 03 | BOA | Feasible: False | No feasible solution found
# Run 04 | BOA | Feasible: False | No feasible solution found
# Run 05 | BOA | Feasible: False | No feasible solution found
# Run 06 | BOA | Feasible: False | No feasible solution found
# Run 07 | BOA | Feasible: False | No feasible solution found
# Run 08 | BOA | Feasible: False | No feasible solution found
# Run 09 | BOA | Feasible: False | No feasible solution found
# Run 10 | BOA | Feasible: False | No feasible solution found
# Run 11 | BOA | Feasible: False | No feasible solution found
# Run 12 | BOA | Feasible: False | No feasible solution found
# Run 13 | BOA | Feasible: False | No feasible solution found
# Run 14 | BOA | Feasible: False | No feasible solution found
# Run 15 | BOA | Feasible: False | No feasible solution found
# Run 16 | BOA | Feasible: False | No feasible solution found
# Run 17 | BOA | Feasible: False | No feasible solution found
# Run 18 | BOA | Feasible: False | No feasible solution found
# Run 19 | BOA | Feasible: False | No feasible solution found
# Run 20 | BOA | Feasible: False | No feasible solution found
# Run 21 | BOA | Feasible: False | No feasible solution found
# Run 22 | BOA | Feasible: False | No feasible solution found
# Run 23 | BOA | Feasible: False | No feasible solution found
# Run 24 | BOA | Feasible: False | No feasible solution found
# Run 25 | BOA | Feasible: False | No feasible solution found
# Run 26 | BOA | Feasible: False | No feasible solution found
# Run 27 | BOA | Feasible: False | No feasible solution found
# Run 28 | BOA | Feasible: False | No feasible solution found
# Run 29 | BOA | Feasible: False | No feasible solution found
# Run 30 | BOA | Feasible: False | No feasible solution found
#
# ==============================================================================================================
# SUMMARY TABLE
# ==============================================================================================================
# Rank  Algorithm         Feasible    Mean          Std           Min           Max
# 1     BOA               0/30        nan           nan           nan           nan
#
# ====================================================================================================================================================================================
# OPTIMAL RELAY COORDINATION PARAMETERS (TD, IP, TI) AND TOTAL RUN TIMES
# OBTAINED FROM THE BOA ALGORITHM
# ====================================================================================================================================================================================
# Algorithm         Relay-1 (td, Ip, ti)        Relay-2 (td, Ip, ti)        Relay-3 (td, Ip, ti)        Relay-4 (td, Ip, ti)        Relay-5 (td, Ip, ti)        Relay-6 (td, Ip, ti)        Total ti
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# BOA               NO FEASIBLE SOLUTION        NO FEASIBLE SOLUTION        NO FEASIBLE SOLUTION        NO FEASIBLE SOLUTION        NO FEASIBLE SOLUTION        NO FEASIBLE SOLUTION        nan
#
# Saved summary CSV: C:\Users\ESEL\Desktop\SGuA\SGuA_rev\outputs_boa\boa_orc_summary_statistics.csv
# Saved run-level CSV: C:\Users\ESEL\Desktop\SGuA\SGuA_rev\outputs_boa\boa_orc_run_results.csv
# Saved publication CSV: C:\Users\ESEL\Desktop\SGuA\SGuA_rev\outputs_boa\boa_orc_publication_table.csv
# Saved convergence CSV: C:\Users\ESEL\Desktop\SGuA\SGuA_rev\outputs_boa\boa_or_c_feasible_curves.csv
# Saved convergence figure: C:\Users\ESEL\Desktop\SGuA\SGuA_rev\outputs_boa\boa_orc_mean_convergence.png
