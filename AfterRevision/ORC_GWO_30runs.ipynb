# %%
from orc_meta_common import GWO, run_algorithm_experiments, save_single_algorithm_outputs

if __name__ == "__main__":
    N_RUNS = 30
    POP_SIZE = 100
    ITERATIONS = 1000
    PENALTY_WEIGHT = 1e6
    BASE_SEED = 123

    problem, results, summary = run_algorithm_experiments(
        optimizer_cls=GWO,
        algorithm_name="GWO",
        n_runs=N_RUNS,
        P=POP_SIZE,
        G=ITERATIONS,
        penalty_weight=PENALTY_WEIGHT,
        base_seed=BASE_SEED,
        optimizer_kwargs={},
    )

    save_single_algorithm_outputs(
        problem=problem,
        results=results,
        summary=summary,
        algorithm_name="GWO",
        outdir_name="outputs_gwo",
    )
# Out:
# ...
# GWO ON THE ORC PROBLEM
# ...
# Run 01 | GWO | Feasible: True | Best Fitness (sum_ti): 6.908117
# Run 02 | GWO | Feasible: True | Best Fitness (sum_ti): 6.907755
# Run 03 | GWO | Feasible: True | Best Fitness (sum_ti): 6.908718
# Run 04 | GWO | Feasible: True | Best Fitness (sum_ti): 6.908917
# Run 05 | GWO | Feasible: True | Best Fitness (sum_ti): 6.907551
# Run 06 | GWO | Feasible: True | Best Fitness (sum_ti): 6.906852
# Run 07 | GWO | Feasible: True | Best Fitness (sum_ti): 6.904849
# Run 08 | GWO | Feasible: True | Best Fitness (sum_ti): 6.909793
# Run 09 | GWO | Feasible: True | Best Fitness (sum_ti): 6.909775
# Run 10 | GWO | Feasible: True | Best Fitness (sum_ti): 6.907655
# Run 11 | GWO | Feasible: True | Best Fitness (sum_ti): 6.910132
# Run 12 | GWO | Feasible: True | Best Fitness (sum_ti): 6.908930
# Run 13 | GWO | Feasible: True | Best Fitness (sum_ti): 6.909130
# Run 14 | GWO | Feasible: True | Best Fitness (sum_ti): 6.913677
# ...
