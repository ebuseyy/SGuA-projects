# %%
from orc_meta_common import WOA, run_algorithm_experiments, save_single_algorithm_outputs

if __name__ == "__main__":
    N_RUNS = 30
    POP_SIZE = 100
    ITERATIONS = 1000
    PENALTY_WEIGHT = 1e6
    BASE_SEED = 123

    problem, results, summary = run_algorithm_experiments(
        optimizer_cls=WOA,
        algorithm_name="WOA",
        n_runs=N_RUNS,
        P=POP_SIZE,
        G=ITERATIONS,
        penalty_weight=PENALTY_WEIGHT,
        base_seed=BASE_SEED,
        optimizer_kwargs={},
    )

    save_single_algorithm_outputs(
        problem=problem,
        results=results,
        summary=summary,
        algorithm_name="WOA",
        outdir_name="outputs_woa",
    )
# Out:
# ====================================================================================================
# WOA ON THE ORC PROBLEM
# ====================================================================================================
# Run 01 | WOA | Feasible: True | Best Fitness (sum_ti): 6.908538
# Run 02 | WOA | Feasible: True | Best Fitness (sum_ti): 6.913636
# Run 03 | WOA | Feasible: True | Best Fitness (sum_ti): 6.908567
# Run 04 | WOA | Feasible: True | Best Fitness (sum_ti): 6.931674
# Run 05 | WOA | Feasible: True | Best Fitness (sum_ti): 6.909382
# Run 06 | WOA | Feasible: True | Best Fitness (sum_ti): 6.912736
# Run 07 | WOA | Feasible: True | Best Fitness (sum_ti): 6.911123
# Run 08 | WOA | Feasible: True | Best Fitness (sum_ti): 6.915952
# Run 09 | WOA | Feasible: True | Best Fitness (sum_ti): 6.914745
# Run 10 | WOA | Feasible: True | Best Fitness (sum_ti): 6.907591
# Run 11 | WOA | Feasible: True | Best Fitness (sum_ti): 6.905920
# Run 12 | WOA | Feasible: True | Best Fitness (sum_ti): 6.907417
# Run 13 | WOA | Feasible: True | Best Fitness (sum_ti): 6.912438
# Run 14 | WOA | Feasible: True | Best Fitness (sum_ti): 6.919730
# Run 15 | WOA | Feasible: True | Best Fitness (sum_ti): 6.922442
# Run 16 | WOA | Feasible: True | Best Fitness (sum_ti): 6.917463
# Run 17 | WOA | Feasible: True | Best Fitness (sum_ti): 6.952304
# Run 18 | WOA | Feasible: True | Best Fitness (sum_ti): 6.995100
# Run 19 | WOA | Feasible: True | Best Fitness (sum_ti): 6.912374
# Run 20 | WOA | Feasible: True | Best Fitness (sum_ti): 6.903110
# Run 21 | WOA | Feasible: True | Best Fitness (sum_ti): 6.919878
# Run 22 | WOA | Feasible: True | Best Fitness (sum_ti): 6.913972
# Run 23 | WOA | Feasible: True | Best Fitness (sum_ti): 6.906311
# Run 24 | WOA | Feasible: True | Best Fitness (sum_ti): 6.928314
# Run 25 | WOA | Feasible: True | Best Fitness (sum_ti): 6.908635
# Run 26 | WOA | Feasible: True | Best Fitness (sum_ti): 6.926733
# Run 27 | WOA | Feasible: True | Best Fitness (sum_ti): 6.908997
# Run 28 | WOA | Feasible: True | Best Fitness (sum_ti): 6.903840
# Run 29 | WOA | Feasible: True | Best Fitness (sum_ti): 6.924479
# Run 30 | WOA | Feasible: True | Best Fitness (sum_ti): 6.909393
#
# ==============================================================================================================
# SUMMARY TABLE
# ==============================================================================================================
# Rank  Algorithm         Feasible    Mean          Std           Min           Max
# 1     WOA               30/30       6.917760      0.017480      6.903110      6.995100
#
# Best feasible run for WOA
# Relay     td          Ip(A)       Ti(s)
# Relay-1   0.541426    125.038     1.601211
# Relay-2   0.452609    523.116     1.301082
# Relay-3   0.380857    420.000     1.000058
# Relay-4   0.352454    507.454     1.000077
# Relay-5   0.327529    600.000     1.000528
# Relay-6   0.388240    400.000     1.000153
#
# Constraint Check:
# 1 <= t1 <= 2.2 : True
# 1 <= t2 <= 2.2 : True
# 1 <= t3 <= 2.2 : True
# 1 <= t4 <= 2.2 : True
# 1 <= t5 <= 2.2 : True
# 1 <= t6 <= 2.2 : True
# t1 - t2 >= 0.3 : True   value = 0.300129
# t2 - t3 >= 0.3 : True   value = 0.301024
# t2 - t4 >= 0.3 : True   value = 0.301005
# t2 - t5 >= 0.3 : True   value = 0.300554
# t2 - t6 >= 0.3 : True   value = 0.300929
#
# Best fitness (sum_ti): 6.903110
# Function evaluations: 100000
#
# ====================================================================================================================================================================================
# OPTIMAL RELAY COORDINATION PARAMETERS (TD, IP, TI) AND TOTAL RUN TIMES
# OBTAINED FROM THE WOA ALGORITHM
# ====================================================================================================================================================================================
# Algorithm         Relay-1 (td, Ip, ti)        Relay-2 (td, Ip, ti)        Relay-3 (td, Ip, ti)        Relay-4 (td, Ip, ti)        Relay-5 (td, Ip, ti)        Relay-6 (td, Ip, ti)        Total ti
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# WOA               0.5414 / 125.04 / 1.6012    0.4526 / 523.12 / 1.3011    0.3809 / 420.00 / 1.0001    0.3525 / 507.45 / 1.0001    0.3275 / 600.00 / 1.0005    0.3882 / 400.00 / 1.0002    6.9031
#
# Saved summary CSV: C:\Users\ESEL\Desktop\SGuA\SGuA_rev\outputs_woa\woa_orc_summary_statistics.csv
# Saved run-level CSV: C:\Users\ESEL\Desktop\SGuA\SGuA_rev\outputs_woa\woa_orc_run_results.csv
# Saved publication CSV: C:\Users\ESEL\Desktop\SGuA\SGuA_rev\outputs_woa\woa_orc_publication_table.csv
# Saved convergence CSV: C:\Users\ESEL\Desktop\SGuA\SGuA_rev\outputs_woa\woa_or_c_feasible_curves.csv
# Saved distribution figure: C:\Users\ESEL\Desktop\SGuA\SGuA_rev\outputs_woa\woa_orc_distribution_boxplot.png
# Saved convergence figure: C:\Users\ESEL\Desktop\SGuA\SGuA_rev\outputs_woa\woa_orc_mean_convergence.png
