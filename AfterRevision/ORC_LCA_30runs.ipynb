# %%
from orc_meta_common import LCA, run_algorithm_experiments, save_single_algorithm_outputs

if __name__ == "__main__":
    N_RUNS = 30
    POP_SIZE = 100
    ITERATIONS = 1000
    PENALTY_WEIGHT = 1e6
    BASE_SEED = 123

    problem, results, summary = run_algorithm_experiments(
        optimizer_cls=LCA,
        algorithm_name="LCA",
        n_runs=N_RUNS,
        P=POP_SIZE,
        G=ITERATIONS,
        penalty_weight=PENALTY_WEIGHT,
        base_seed=BASE_SEED,
        optimizer_kwargs={},
    )

    save_single_algorithm_outputs(
        problem=problem,
        results=results,
        summary=summary,
        algorithm_name="LCA",
        outdir_name="outputs_lca",
    )
# Out:
# ====================================================================================================
# LCA ON THE ORC PROBLEM
# ====================================================================================================
# Run 01 | LCA | Feasible: True | Best Fitness (sum_ti): 6.901760
# Run 02 | LCA | Feasible: True | Best Fitness (sum_ti): 6.900371
# Run 03 | LCA | Feasible: True | Best Fitness (sum_ti): 6.900515
# Run 04 | LCA | Feasible: True | Best Fitness (sum_ti): 6.900401
# Run 05 | LCA | Feasible: True | Best Fitness (sum_ti): 6.900367
# Run 06 | LCA | Feasible: True | Best Fitness (sum_ti): 6.901433
# Run 07 | LCA | Feasible: True | Best Fitness (sum_ti): 6.904203
# Run 08 | LCA | Feasible: True | Best Fitness (sum_ti): 6.955469
# Run 09 | LCA | Feasible: True | Best Fitness (sum_ti): 6.914288
# Run 10 | LCA | Feasible: True | Best Fitness (sum_ti): 6.900706
# Run 11 | LCA | Feasible: True | Best Fitness (sum_ti): 6.903070
# Run 12 | LCA | Feasible: True | Best Fitness (sum_ti): 6.911620
# Run 13 | LCA | Feasible: True | Best Fitness (sum_ti): 6.900571
# Run 14 | LCA | Feasible: True | Best Fitness (sum_ti): 6.900369
# Run 15 | LCA | Feasible: True | Best Fitness (sum_ti): 6.938794
# Run 16 | LCA | Feasible: True | Best Fitness (sum_ti): 6.901010
# Run 17 | LCA | Feasible: True | Best Fitness (sum_ti): 6.939268
# Run 18 | LCA | Feasible: True | Best Fitness (sum_ti): 6.901334
# Run 19 | LCA | Feasible: True | Best Fitness (sum_ti): 6.937882
# Run 20 | LCA | Feasible: True | Best Fitness (sum_ti): 6.906104
# Run 21 | LCA | Feasible: True | Best Fitness (sum_ti): 6.902110
# Run 22 | LCA | Feasible: True | Best Fitness (sum_ti): 6.901195
# Run 23 | LCA | Feasible: True | Best Fitness (sum_ti): 6.940148
# Run 24 | LCA | Feasible: True | Best Fitness (sum_ti): 6.900457
# Run 25 | LCA | Feasible: True | Best Fitness (sum_ti): 6.900751
# Run 26 | LCA | Feasible: True | Best Fitness (sum_ti): 6.917468
# Run 27 | LCA | Feasible: True | Best Fitness (sum_ti): 6.910757
# Run 28 | LCA | Feasible: True | Best Fitness (sum_ti): 6.901250
# Run 29 | LCA | Feasible: True | Best Fitness (sum_ti): 6.900284
# Run 30 | LCA | Feasible: True | Best Fitness (sum_ti): 6.909114
#
# ==============================================================================================================
# SUMMARY TABLE
# ==============================================================================================================
# Rank  Algorithm         Feasible    Mean          Std           Min           Max
# 1     LCA               30/30       6.910102      0.015313      6.900284      6.955469
#
# Best feasible run for LCA
# Relay     td          Ip(A)       Ti(s)
# Relay-1   0.541190    124.985     1.600215
# Relay-2   0.443009    548.549     1.300052
# Relay-3   0.385732    406.563     1.000007
# Relay-4   0.352762    506.329     1.000008
# Relay-5   0.325708    606.658     1.000002
# Relay-6   0.383649    412.220     1.000000
#
# Constraint Check:
# 1 <= t1 <= 2.2 : True
# 1 <= t2 <= 2.2 : True
# 1 <= t3 <= 2.2 : True
# 1 <= t4 <= 2.2 : True
# 1 <= t5 <= 2.2 : True
# 1 <= t6 <= 2.2 : True
# t1 - t2 >= 0.3 : True   value = 0.300163
# t2 - t3 >= 0.3 : True   value = 0.300046
# t2 - t4 >= 0.3 : True   value = 0.300044
# t2 - t5 >= 0.3 : True   value = 0.300051
# t2 - t6 >= 0.3 : True   value = 0.300052
#
# Best fitness (sum_ti): 6.900284
# Function evaluations: 100000
#
# ====================================================================================================================================================================================
# OPTIMAL RELAY COORDINATION PARAMETERS (TD, IP, TI) AND TOTAL RUN TIMES
# OBTAINED FROM THE LCA ALGORITHM
# ====================================================================================================================================================================================
# Algorithm         Relay-1 (td, Ip, ti)        Relay-2 (td, Ip, ti)        Relay-3 (td, Ip, ti)        Relay-4 (td, Ip, ti)        Relay-5 (td, Ip, ti)        Relay-6 (td, Ip, ti)        Total ti
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# LCA               0.5412 / 124.99 / 1.6002    0.4430 / 548.55 / 1.3001    0.3857 / 406.56 / 1.0000    0.3528 / 506.33 / 1.0000    0.3257 / 606.66 / 1.0000    0.3836 / 412.22 / 1.0000    6.9003
#
# Saved summary CSV: C:\Users\ESEL\Desktop\SGuA\SGuA_rev\outputs_lca\lca_orc_summary_statistics.csv
# Saved run-level CSV: C:\Users\ESEL\Desktop\SGuA\SGuA_rev\outputs_lca\lca_orc_run_results.csv
# Saved publication CSV: C:\Users\ESEL\Desktop\SGuA\SGuA_rev\outputs_lca\lca_orc_publication_table.csv
# Saved convergence CSV: C:\Users\ESEL\Desktop\SGuA\SGuA_rev\outputs_lca\lca_or_c_feasible_curves.csv
# Saved distribution figure: C:\Users\ESEL\Desktop\SGuA\SGuA_rev\outputs_lca\lca_orc_distribution_boxplot.png
# Saved convergence figure: C:\Users\ESEL\Desktop\SGuA\SGuA_rev\outputs_lca\lca_orc_mean_convergence.png
